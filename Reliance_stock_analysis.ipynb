# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import datetime

# %%
data = pd.read_csv("RELIANCE.NS.csv")

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0     2016-07-01   481.807953   483.813934   480.445862   482.154663
# 1     2016-07-04   483.170044   492.135040   483.170044   488.717438
# 2     2016-07-05   488.420258   496.741394   485.547485   491.887390
# 3     2016-07-07   491.590210   495.552643   488.445038   489.311798
# 4     2016-07-08   488.866028   489.856659   483.591034   484.606415
# ...          ...          ...          ...          ...          ...
# 1228  2021-06-24  2206.850098  2214.600098  2140.000000  2153.500000
# 1229  2021-06-25  2153.500000  2153.500000  2081.100098  2104.449951
# 1230  2021-06-28  2122.000000  2126.500000  2081.000000  2086.000000
# 1231  2021-06-29  2089.500000  2109.000000  2084.100098  2087.800049
# 1232  2021-06-30  2096.250000  2122.649902  2091.050049  2110.649902
#
#         Adj Close      Volume
# 0      469.810242   3050603.0
# 1      476.205017   3601316.0
# 2      479.293793   5242583.0
# ...

# %%
Month = pd.to_datetime(data['Date'])

# %%
Month = Month.dt.month_name(locale="English")

# %%
Month
# Out:
# 0       July
# 1       July
# 2       July
# 3       July
# 4       July
#         ...
# 1228    June
# 1229    June
# 1230    June
# 1231    June
# 1232    June
# Name: Date, Length: 1233, dtype: object

# %%
data['Month'] =Month

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0     2016-07-01   481.807953   483.813934   480.445862   482.154663
# 1     2016-07-04   483.170044   492.135040   483.170044   488.717438
# 2     2016-07-05   488.420258   496.741394   485.547485   491.887390
# 3     2016-07-07   491.590210   495.552643   488.445038   489.311798
# 4     2016-07-08   488.866028   489.856659   483.591034   484.606415
# ...          ...          ...          ...          ...          ...
# 1228  2021-06-24  2206.850098  2214.600098  2140.000000  2153.500000
# 1229  2021-06-25  2153.500000  2153.500000  2081.100098  2104.449951
# 1230  2021-06-28  2122.000000  2126.500000  2081.000000  2086.000000
# 1231  2021-06-29  2089.500000  2109.000000  2084.100098  2087.800049
# 1232  2021-06-30  2096.250000  2122.649902  2091.050049  2110.649902
#
#         Adj Close      Volume Month
# 0      469.810242   3050603.0  July
# 1      476.205017   3601316.0  July
# ...

# %%
 data =data.groupby(Month).sum()

# %%
data
# Out:
#                     Open           High            Low          Close  \
# Date
# April      117392.791196  119042.592646  115946.206055  117449.920172
# August     121991.134402  123311.537050  120417.096594  121829.575440
# December   127948.268215  129029.933104  126492.969792  127799.373534
# February   118222.497069  119741.965998  116978.200594  118426.850249
# January    132058.857608  133230.403689  130482.497737  131644.055051
# July       122186.327972  123865.451112  120745.382633  122439.731695
# June       143359.783753  145113.476256  141723.723328  143333.635313
# March      121705.192749  123713.911625  119595.535887  121509.792180
# May        131434.158815  132820.957946  129798.150336  131091.199343
# November   119922.444305  121149.383727  118356.408843  119544.136962
# October    121784.708859  123223.916687  119936.626218  121455.557069
# September  121805.279296  123347.826900  120273.090915  121760.119209
#
#                Adj Close        Volume
# Date
# ...

# %%
data = data.reset_index()

# %%
data
# Out:
#          Date           Open           High            Low          Close  \
# 0       April  117392.791196  119042.592646  115946.206055  117449.920172
# 1      August  121991.134402  123311.537050  120417.096594  121829.575440
# 2    December  127948.268215  129029.933104  126492.969792  127799.373534
# 3    February  118222.497069  119741.965998  116978.200594  118426.850249
# 4     January  132058.857608  133230.403689  130482.497737  131644.055051
# 5        July  122186.327972  123865.451112  120745.382633  122439.731695
# 6        June  143359.783753  145113.476256  141723.723328  143333.635313
# 7       March  121705.192749  123713.911625  119595.535887  121509.792180
# 8         May  131434.158815  132820.957946  129798.150336  131091.199343
# 9    November  119922.444305  121149.383727  118356.408843  119544.136962
# 10    October  121784.708859  123223.916687  119936.626218  121455.557069
# 11  September  121805.279296  123347.826900  120273.090915  121760.119209
#
# ...

# %%
avg_price = (data['High'] + data['Low'])/2

# %%
data['avg_price'] = avg_price

# %%
data=data[['Date','avg_price']]

# %%
data
# Out:
#          Date      avg_price
# 0       April  117494.399350
# 1      August  121864.316822
# 2    December  127761.451448
# 3    February  118360.083296
# 4     January  131856.450713
# 5        July  122305.416873
# 6        June  143418.599792
# 7       March  121654.723756
# 8         May  131309.554141
# 9    November  119752.896285
# 10    October  121580.271452
# 11  September  121810.458907

# %%
fig = plt.figure(figsize =(10,10))
plt.pie(data['avg_price'], labels = data['Date'],autopct="%.2f")
plt.show()
